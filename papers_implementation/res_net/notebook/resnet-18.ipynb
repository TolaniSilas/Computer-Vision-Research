# %%
print("resnet-18")
# Out:
# Running cells with 'ViT (3.10.12) (Python 3.10.12)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/thaguymaxx/Documents/Computer-Vision-Research/papers_implementation/ViT/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
